# %%
import os
os.chdir(r'C:\Users\Lenovo\Documents')

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score
from timeseires.utils.to_split import to_split
from timeseires.utils.multivariate_multi_step import multivariate_multi_step
from timeseires.utils.multivariate_single_step import multivariate_single_step
from timeseires.utils.univariate_multi_step import univariate_multi_step
from timeseires.utils.univariate_single_step import univariate_single_step
from timeseires.utils.CosineAnnealingLRS import CosineAnnealingLRS
from timeseires.callbacks.EpochCheckpoint import EpochCheckpoint
from tensorflow.keras.callbacks import ModelCheckpoint
from timeseires.callbacks.TrainingMonitor import TrainingMonitor
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import LSTM, Bidirectional, Add
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv1D,TimeDistributed
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten,MaxPooling1D,Concatenate,AveragePooling1D, GlobalMaxPooling1D, Input
from tensorflow.keras.models import Sequential,Model
import pandas as pd
import time, pickle
import numpy as np
import tensorflow.keras.backend as K
import tensorflow
from tensorflow.keras.layers import Input, Reshape, Lambda
from tensorflow.keras.layers import Layer, Flatten, LeakyReLU, concatenate, Dense
from tensorflow.keras.regularizers import l2
import glob
import h5py
import matplotlib.pyplot as plt
from keras.callbacks import Callback

# %%
#lookback = 24
model = None
start_epoch = 0
time_steps=24
num_features=21

# %%
def MLP():
    model = Sequential()
    model.add(Flatten(input_shape=(time_steps , num_features)))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1))
    return model

# %%
model1 = MLP()
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 504)               0
#
#  dense (Dense)               (None, 32)                16160
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 16,193
# Trainable params: 16,193
# Non-trainable params: 0
# _________________________________________________________________

# %%
tensorflow.keras.utils.plot_model(model1 )
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
checkpoints = r'C:\Users\Lenovo\Documents\lab11\lab\E1-cp-{epoch:04d}-loss{val_loss:.2f}.h5'
OUTPUT_PATH = r'C:\Users\Lenovo\Documents\lab11\lab'
FIG_PATH = os.path.sep.join([OUTPUT_PATH,"\history.png"])
JSON_PATH = os.path.sep.join([OUTPUT_PATH,"\history.json"])

# %%
os.path.exists(JSON_PATH)
# Out:
# False

# %%
# construct the callback to save only the *best* model to disk
# based on the validation loss
EpochCheckpoint1 = ModelCheckpoint(checkpoints,
                             monitor="val_loss",
                             save_best_only=True, 
                             verbose=1)
TrainingMonitor1=TrainingMonitor(FIG_PATH, jsonPath=JSON_PATH, startAt=start_epoch)

# construct the set of callbacks
callbacks = [EpochCheckpoint1,TrainingMonitor1]

# %%
# if there is no specific model checkpoint supplied, then initialize
# the network and compile the model
if model is None:
    print("[INFO] compiling model...")
    model =MLP()
    opt = Adam(1e-3)
    model.compile(loss= 'mae', optimizer=opt, metrics=["mae", "mape"])
# otherwise, load the checkpoint from disk
else:
    print("[INFO] loading {}...".format(model))
    model = load_model(model)

    # update the learning rate
    print("[INFO] old learning rate: {}".format(K.get_value(model.optimizer.lr)))
    K.set_value(model.optimizer.lr, 1e-4)
    print("[INFO] new learning rate: {}".format(K.get_value(model.optimizer.lr)))
# Out:
# [INFO] compiling model...

# %%
import os
path_dataset =r'C:\Users\Lenovo\Documents\lab11'
path_tr = os.path.join(path_dataset, 'train.csv')
df_tr = pd.read_csv(path_tr)
train_set = df_tr.iloc[:].values
path_v = os.path.join(path_dataset, 'validation.csv')
df_v = pd.read_csv(path_v)
validation_set = df_v.iloc[:].values 
path_te = os.path.join(path_dataset, 'test.csv')
df_te = pd.read_csv(path_te)
test_set = df_te.iloc[:].values 

path_scaler = os.path.join(path_dataset, 'AEP_scaler.pkl')
scaler         = pickle.load(open(path_scaler, 'rb'))

train_set.shape, validation_set.shape, test_set.shape
# Out:
# e:\anaconda\envs\dsp_tf\lib\site-packages\sklearn\base.py:380: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.0.2 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ((860, 21), (90, 21), (30, 21))

# %%
start = time.time()
train_X , train_y = univariate_multi_step(train_set, time_steps, target_col=0,target_len=1)
validation_X, validation_y = univariate_multi_step(validation_set, time_steps, target_col=0,target_len=1)
test_X, test_y = univariate_multi_step(test_set, time_steps, target_col=0,target_len=1)
print('Time Consumed', time.time()-start, "sec")
# Out:
# Time Consumed 0.007073879241943359 sec

# %%
train_X.shape
# Out:
# (835, 24, 21)

# %%
epochs = 60
verbose = 1 #0
batch_size = 32
History = model.fit(train_X,
                        train_y,
                        batch_size=batch_size,   
                        epochs = epochs, 
                        validation_data = (validation_X,validation_y),
                        callbacks=callbacks,
                    verbose = verbose)
# Out:
# Epoch 1/60
# 20/27 [=====================>........] - ETA: 0s - loss: 0.1604 - mae: 0.1604 - mape: 88.9203
# Epoch 1: val_loss improved from inf to 0.05309, saving model to C:\Users\Lenovo\Documents\lab11\lab\E1-cp-0001-loss0.05.h5
# 27/27 [==============================] - 2s 30ms/step - loss: 0.1436 - mae: 0.1436 - mape: 79.4318 - val_loss: 0.0531 - val_mae: 0.0531 - val_mape: 16.2812
# Epoch 2/60
# 27/27 [==============================] - ETA: 0s - loss: 0.0749 - mae: 0.0749 - mape: 38.5296
# Epoch 2: val_loss did not improve from 0.05309
# 27/27 [==============================] - 1s 41ms/step - loss: 0.0749 - mae: 0.0749 - mape: 38.5296 - val_loss: 0.0786 - val_mae: 0.0786 - val_mape: 25.9367
# Epoch 3/60
# 14/27 [==============>...............] - ETA: 0s - loss: 0.0576 - mae: 0.0576 - mape: 30.4009
# Epoch 3: val_loss improved from 0.05309 to 0.04056, saving model to C:\Users\Lenovo\Documents\lab11\lab\E1-cp-0003-loss0.04.h5
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0541 - mae: 0.0541 - mape: 28.4508 - val_loss: 0.0406 - val_mae: 0.0406 - val_mape: 13.0411
# Epoch 4/60
# 21/27 [======================>.......] - ETA: 0s - loss: 0.0467 - mae: 0.0467 - mape: 24.9532
# Epoch 4: val_loss did not improve from 0.04056
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0467 - mae: 0.0467 - mape: 23.7588 - val_loss: 0.1052 - val_mae: 0.1052 - val_mape: 33.2805
# Epoch 5/60
# 14/27 [==============>...............] - ETA: 0s - loss: 0.0485 - mae: 0.0485 - mape: 29.7856
# Epoch 5: val_loss did not improve from 0.04056
# 27/27 [==============================] - 1s 26ms/step - loss: 0.0484 - mae: 0.0484 - mape: 26.5869 - val_loss: 0.0670 - val_mae: 0.0670 - val_mape: 24.3170
# Epoch 6/60
# 25/27 [==========================>...] - ETA: 0s - loss: 0.0469 - mae: 0.0469 - mape: 24.1447
# Epoch 6: val_loss did not improve from 0.04056
# 27/27 [==============================] - 1s 48ms/step - loss: 0.0467 - mae: 0.0467 - mape: 23.9209 - val_loss: 0.0887 - val_mae: 0.0887 - val_mape: 29.3500
# Epoch 7/60
# 23/27 [========================>.....] - ETA: 0s - loss: 0.0415 - mae: 0.0415 - mape: 25.7019
# Epoch 7: val_loss improved from 0.04056 to 0.03674, saving model to C:\Users\Lenovo\Documents\lab11\lab\E1-cp-0007-loss0.04.h5
# 27/27 [==============================] - 1s 26ms/step - loss: 0.0411 - mae: 0.0411 - mape: 24.9427 - val_loss: 0.0367 - val_mae: 0.0367 - val_mape: 14.3708
# Epoch 8/60
# 27/27 [==============================] - ETA: 0s - loss: 0.0460 - mae: 0.0460 - mape: 25.3374
# Epoch 8: val_loss did not improve from 0.03674
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0460 - mae: 0.0460 - mape: 25.3374 - val_loss: 0.0443 - val_mae: 0.0443 - val_mape: 13.9868
# Epoch 9/60
# 18/27 [===================>..........] - ETA: 0s - loss: 0.0487 - mae: 0.0487 - mape: 25.8039
# Epoch 9: val_loss did not improve from 0.03674
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0468 - mae: 0.0468 - mape: 23.9181 - val_loss: 0.0651 - val_mae: 0.0651 - val_mape: 21.8480
# Epoch 10/60
# 23/27 [========================>.....] - ETA: 0s - loss: 0.0406 - mae: 0.0406 - mape: 18.5599
# Epoch 10: val_loss did not improve from 0.03674
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0396 - mae: 0.0396 - mape: 18.6046 - val_loss: 0.0371 - val_mae: 0.0371 - val_mape: 14.6896
# Epoch 11/60
# 21/27 [======================>.......] - ETA: 0s - loss: 0.0493 - mae: 0.0493 - mape: 25.2239
# Epoch 11: val_loss did not improve from 0.03674
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0470 - mae: 0.0470 - mape: 23.5329 - val_loss: 0.0715 - val_mae: 0.0715 - val_mape: 22.8753
# Epoch 12/60
# 22/27 [=======================>......] - ETA: 0s - loss: 0.0436 - mae: 0.0436 - mape: 21.2052
# Epoch 12: val_loss improved from 0.03674 to 0.03412, saving model to C:\Users\Lenovo\Documents\lab11\lab\E1-cp-0012-loss0.03.h5
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0435 - mae: 0.0435 - mape: 21.2550 - val_loss: 0.0341 - val_mae: 0.0341 - val_mape: 10.9820
# Epoch 13/60
# 19/27 [====================>.........] - ETA: 0s - loss: 0.0369 - mae: 0.0369 - mape: 17.0368
# Epoch 13: val_loss improved from 0.03412 to 0.03226, saving model to C:\Users\Lenovo\Documents\lab11\lab\E1-cp-0013-loss0.03.h5
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0358 - mae: 0.0358 - mape: 16.9378 - val_loss: 0.0323 - val_mae: 0.0323 - val_mape: 10.9391
# Epoch 14/60
# 22/27 [=======================>......] - ETA: 0s - loss: 0.0349 - mae: 0.0349 - mape: 17.8538
# Epoch 14: val_loss improved from 0.03226 to 0.02317, saving model to C:\Users\Lenovo\Documents\lab11\lab\E1-cp-0014-loss0.02.h5
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0337 - mae: 0.0337 - mape: 17.3485 - val_loss: 0.0232 - val_mae: 0.0232 - val_mape: 7.5183
# Epoch 15/60
# 20/27 [=====================>........] - ETA: 0s - loss: 0.0340 - mae: 0.0340 - mape: 14.7564
# Epoch 15: val_loss did not improve from 0.02317
# 27/27 [==============================] - 0s 15ms/step - loss: 0.0320 - mae: 0.0320 - mape: 15.2848 - val_loss: 0.0685 - val_mae: 0.0685 - val_mape: 21.3693
# Epoch 16/60
# 15/27 [===============>..............] - ETA: 0s - loss: 0.0383 - mae: 0.0383 - mape: 18.3427
# Epoch 16: val_loss did not improve from 0.02317
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0362 - mae: 0.0362 - mape: 18.4882 - val_loss: 0.0401 - val_mae: 0.0401 - val_mape: 11.6729
# Epoch 17/60
# 17/27 [=================>............] - ETA: 0s - loss: 0.0300 - mae: 0.0300 - mape: 14.8238
# Epoch 17: val_loss did not improve from 0.02317
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0316 - mae: 0.0316 - mape: 16.2917 - val_loss: 0.0568 - val_mae: 0.0568 - val_mape: 16.3821
# Epoch 18/60
# 15/27 [===============>..............] - ETA: 0s - loss: 0.0342 - mae: 0.0342 - mape: 16.1631
# Epoch 18: val_loss did not improve from 0.02317
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0329 - mae: 0.0329 - mape: 15.0902 - val_loss: 0.0590 - val_mae: 0.0590 - val_mape: 17.9692
# Epoch 19/60
# 20/27 [=====================>........] - ETA: 0s - loss: 0.0316 - mae: 0.0316 - mape: 14.8256
# Epoch 19: val_loss did not improve from 0.02317
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0311 - mae: 0.0311 - mape: 15.1841 - val_loss: 0.0311 - val_mae: 0.0311 - val_mape: 12.1683
# Epoch 20/60
# 18/27 [===================>..........] - ETA: 0s - loss: 0.0369 - mae: 0.0369 - mape: 19.0843
# Epoch 20: val_loss did not improve from 0.02317
# 27/27 [==============================] - 0s 14ms/step - loss: 0.0347 - mae: 0.0347 - mape: 16.4448 - val_loss: 0.0257 - val_mae: 0.0257 - val_mape: 9.2853
# Epoch 21/60
# 18/27 [===================>..........] - ETA: 0s - loss: 0.0307 - mae: 0.0307 - mape: 12.7054
# Epoch 21: val_loss did not improve from 0.02317
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0314 - mae: 0.0314 - mape: 14.6311 - val_loss: 0.0662 - val_mae: 0.0662 - val_mape: 20.6344
# Epoch 22/60
# 24/27 [=========================>....] - ETA: 0s - loss: 0.0374 - mae: 0.0374 - mape: 16.2946
# Epoch 22: val_loss did not improve from 0.02317
# 27/27 [==============================] - 0s 15ms/step - loss: 0.0367 - mae: 0.0367 - mape: 16.4791 - val_loss: 0.0329 - val_mae: 0.0329 - val_mape: 11.8809
# Epoch 23/60
# 14/27 [==============>...............] - ETA: 0s - loss: 0.0315 - mae: 0.0315 - mape: 13.4019
# Epoch 23: val_loss did not improve from 0.02317
# 27/27 [==============================] - 0s 13ms/step - loss: 0.0292 - mae: 0.0292 - mape: 13.2748 - val_loss: 0.0302 - val_mae: 0.0302 - val_mape: 11.3905
# Epoch 24/60
# 15/27 [===============>..............] - ETA: 0s - loss: 0.0347 - mae: 0.0347 - mape: 15.4126
# Epoch 24: val_loss did not improve from 0.02317
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0312 - mae: 0.0312 - mape: 14.0858 - val_loss: 0.0295 - val_mae: 0.0295 - val_mape: 8.9496
# Epoch 25/60
# 19/27 [====================>.........] - ETA: 0s - loss: 0.0255 - mae: 0.0255 - mape: 12.3476
# Epoch 25: val_loss did not improve from 0.02317
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0251 - mae: 0.0251 - mape: 12.1734 - val_loss: 0.0390 - val_mae: 0.0390 - val_mape: 11.9446
# Epoch 26/60
# 14/27 [==============>...............] - ETA: 0s - loss: 0.0270 - mae: 0.0270 - mape: 13.1680
# Epoch 26: val_loss did not improve from 0.02317
# 27/27 [==============================] - 0s 15ms/step - loss: 0.0264 - mae: 0.0264 - mape: 11.9025 - val_loss: 0.0429 - val_mae: 0.0429 - val_mape: 15.4774
# Epoch 27/60
# 23/27 [========================>.....] - ETA: 0s - loss: 0.0302 - mae: 0.0302 - mape: 13.8302
# Epoch 27: val_loss did not improve from 0.02317
# 27/27 [==============================] - 0s 15ms/step - loss: 0.0300 - mae: 0.0300 - mape: 14.4539 - val_loss: 0.0249 - val_mae: 0.0249 - val_mape: 8.9487
# Epoch 28/60
# 23/27 [========================>.....] - ETA: 0s - loss: 0.0253 - mae: 0.0253 - mape: 11.9928
# Epoch 28: val_loss did not improve from 0.02317
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0252 - mae: 0.0252 - mape: 11.6469 - val_loss: 0.0333 - val_mae: 0.0333 - val_mape: 12.7877
# Epoch 29/60
# 24/27 [=========================>....] - ETA: 0s - loss: 0.0245 - mae: 0.0245 - mape: 11.2914
# Epoch 29: val_loss did not improve from 0.02317
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0246 - mae: 0.0246 - mape: 11.3909 - val_loss: 0.0258 - val_mae: 0.0258 - val_mape: 8.9713
# Epoch 30/60
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0269 - mae: 0.0269 - mape: 12.5319
# Epoch 30: val_loss did not improve from 0.02317
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0269 - mae: 0.0269 - mape: 12.4993 - val_loss: 0.0397 - val_mae: 0.0397 - val_mape: 14.0603
# Epoch 31/60
# 15/27 [===============>..............] - ETA: 0s - loss: 0.0256 - mae: 0.0256 - mape: 12.1495
# Epoch 31: val_loss did not improve from 0.02317
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0247 - mae: 0.0247 - mape: 11.0520 - val_loss: 0.0241 - val_mae: 0.0241 - val_mape: 8.1018
# Epoch 32/60
# 15/27 [===============>..............] - ETA: 0s - loss: 0.0240 - mae: 0.0240 - mape: 10.7778
# Epoch 32: val_loss did not improve from 0.02317
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0221 - mae: 0.0221 - mape: 9.4291 - val_loss: 0.0247 - val_mae: 0.0247 - val_mape: 8.4055
# Epoch 33/60
# 22/27 [=======================>......] - ETA: 0s - loss: 0.0217 - mae: 0.0217 - mape: 10.0591
# Epoch 33: val_loss did not improve from 0.02317
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0222 - mae: 0.0222 - mape: 10.0452 - val_loss: 0.0449 - val_mae: 0.0449 - val_mape: 16.1610
# Epoch 34/60
# 22/27 [=======================>......] - ETA: 0s - loss: 0.0215 - mae: 0.0215 - mape: 10.6663
# Epoch 34: val_loss did not improve from 0.02317
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0218 - mae: 0.0218 - mape: 10.2644 - val_loss: 0.0300 - val_mae: 0.0300 - val_mape: 8.1362
# Epoch 35/60
# 15/27 [===============>..............] - ETA: 0s - loss: 0.0260 - mae: 0.0260 - mape: 12.2856
# Epoch 35: val_loss did not improve from 0.02317
# 27/27 [==============================] - 0s 15ms/step - loss: 0.0241 - mae: 0.0241 - mape: 10.8088 - val_loss: 0.0294 - val_mae: 0.0294 - val_mape: 10.0635
# Epoch 36/60
# 22/27 [=======================>......] - ETA: 0s - loss: 0.0221 - mae: 0.0221 - mape: 10.0402
# Epoch 36: val_loss did not improve from 0.02317
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0222 - mae: 0.0222 - mape: 9.7333 - val_loss: 0.0276 - val_mae: 0.0276 - val_mape: 9.6107
# Epoch 37/60
# 13/27 [=============>................] - ETA: 0s - loss: 0.0237 - mae: 0.0237 - mape: 10.3752
# Epoch 37: val_loss did not improve from 0.02317
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0235 - mae: 0.0235 - mape: 9.9289 - val_loss: 0.0273 - val_mae: 0.0273 - val_mape: 8.5801
# Epoch 38/60
# 23/27 [========================>.....] - ETA: 0s - loss: 0.0227 - mae: 0.0227 - mape: 9.8019
# Epoch 38: val_loss did not improve from 0.02317
# 27/27 [==============================] - 0s 19ms/step - loss: 0.0227 - mae: 0.0227 - mape: 9.6818 - val_loss: 0.0235 - val_mae: 0.0235 - val_mape: 7.1763
# Epoch 39/60
# 18/27 [===================>..........] - ETA: 0s - loss: 0.0215 - mae: 0.0215 - mape: 8.5993
# Epoch 39: val_loss did not improve from 0.02317
# 27/27 [==============================] - 0s 13ms/step - loss: 0.0212 - mae: 0.0212 - mape: 9.5593 - val_loss: 0.0272 - val_mae: 0.0272 - val_mape: 8.6853
# Epoch 40/60
# 18/27 [===================>..........] - ETA: 0s - loss: 0.0297 - mae: 0.0297 - mape: 11.2318
# Epoch 40: val_loss did not improve from 0.02317
# 27/27 [==============================] - 0s 15ms/step - loss: 0.0302 - mae: 0.0302 - mape: 12.5873 - val_loss: 0.0371 - val_mae: 0.0371 - val_mape: 12.7839
# Epoch 41/60
# 12/27 [============>.................] - ETA: 0s - loss: 0.0231 - mae: 0.0231 - mape: 10.8098
# Epoch 41: val_loss improved from 0.02317 to 0.02179, saving model to C:\Users\Lenovo\Documents\lab11\lab\E1-cp-0041-loss0.02.h5
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0219 - mae: 0.0219 - mape: 10.2480 - val_loss: 0.0218 - val_mae: 0.0218 - val_mape: 6.0164
# Epoch 42/60
# 17/27 [=================>............] - ETA: 0s - loss: 0.0229 - mae: 0.0229 - mape: 9.3840
# Epoch 42: val_loss did not improve from 0.02179
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0229 - mae: 0.0229 - mape: 9.3767 - val_loss: 0.0407 - val_mae: 0.0407 - val_mape: 13.9149
# Epoch 43/60
# 14/27 [==============>...............] - ETA: 0s - loss: 0.0344 - mae: 0.0344 - mape: 15.8497
# Epoch 43: val_loss did not improve from 0.02179
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0304 - mae: 0.0304 - mape: 13.3455 - val_loss: 0.0230 - val_mae: 0.0230 - val_mape: 6.3470
# Epoch 44/60
# 20/27 [=====================>........] - ETA: 0s - loss: 0.0254 - mae: 0.0254 - mape: 12.0008
# Epoch 44: val_loss did not improve from 0.02179
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0245 - mae: 0.0245 - mape: 10.9133 - val_loss: 0.0268 - val_mae: 0.0268 - val_mape: 9.3561
# Epoch 45/60
# 25/27 [==========================>...] - ETA: 0s - loss: 0.0247 - mae: 0.0247 - mape: 11.1102
# Epoch 45: val_loss did not improve from 0.02179
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0244 - mae: 0.0244 - mape: 10.8537 - val_loss: 0.0227 - val_mae: 0.0227 - val_mape: 6.6677
# Epoch 46/60
# 19/27 [====================>.........] - ETA: 0s - loss: 0.0214 - mae: 0.0214 - mape: 9.8689
# Epoch 46: val_loss did not improve from 0.02179
# 27/27 [==============================] - 0s 15ms/step - loss: 0.0220 - mae: 0.0220 - mape: 9.9422 - val_loss: 0.0224 - val_mae: 0.0224 - val_mape: 6.7289
# Epoch 47/60
# 17/27 [=================>............] - ETA: 0s - loss: 0.0250 - mae: 0.0250 - mape: 11.1044
# Epoch 47: val_loss did not improve from 0.02179
# 27/27 [==============================] - 0s 14ms/step - loss: 0.0264 - mae: 0.0264 - mape: 12.4316 - val_loss: 0.0377 - val_mae: 0.0377 - val_mape: 10.6842
# Epoch 48/60
# 18/27 [===================>..........] - ETA: 0s - loss: 0.0398 - mae: 0.0398 - mape: 16.4659
# Epoch 48: val_loss did not improve from 0.02179
# 27/27 [==============================] - 0s 13ms/step - loss: 0.0372 - mae: 0.0372 - mape: 15.5296 - val_loss: 0.0235 - val_mae: 0.0235 - val_mape: 7.7251
# Epoch 49/60
# 19/27 [====================>.........] - ETA: 0s - loss: 0.0203 - mae: 0.0203 - mape: 9.4172
# Epoch 49: val_loss did not improve from 0.02179
# 27/27 [==============================] - 0s 14ms/step - loss: 0.0202 - mae: 0.0202 - mape: 9.0176 - val_loss: 0.0241 - val_mae: 0.0241 - val_mape: 7.9117
# Epoch 50/60
# 21/27 [======================>.......] - ETA: 0s - loss: 0.0204 - mae: 0.0204 - mape: 8.9166
# Epoch 50: val_loss did not improve from 0.02179
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0208 - mae: 0.0208 - mape: 9.1408 - val_loss: 0.0303 - val_mae: 0.0303 - val_mape: 11.0976
# Epoch 51/60
# 16/27 [================>.............] - ETA: 0s - loss: 0.0253 - mae: 0.0253 - mape: 10.8780
# Epoch 51: val_loss did not improve from 0.02179
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0242 - mae: 0.0242 - mape: 10.2570 - val_loss: 0.0276 - val_mae: 0.0276 - val_mape: 9.2580
# Epoch 52/60
# 18/27 [===================>..........] - ETA: 0s - loss: 0.0208 - mae: 0.0208 - mape: 8.5184
# Epoch 52: val_loss did not improve from 0.02179
# 27/27 [==============================] - 0s 13ms/step - loss: 0.0199 - mae: 0.0199 - mape: 8.3569 - val_loss: 0.0263 - val_mae: 0.0263 - val_mape: 9.0299
# Epoch 53/60
# 17/27 [=================>............] - ETA: 0s - loss: 0.0219 - mae: 0.0219 - mape: 9.2841
# Epoch 53: val_loss did not improve from 0.02179
# 27/27 [==============================] - 0s 13ms/step - loss: 0.0223 - mae: 0.0223 - mape: 9.6709 - val_loss: 0.0326 - val_mae: 0.0326 - val_mape: 10.8739
# Epoch 54/60
# 17/27 [=================>............] - ETA: 0s - loss: 0.0245 - mae: 0.0245 - mape: 10.0380
# Epoch 54: val_loss did not improve from 0.02179
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0236 - mae: 0.0236 - mape: 10.2224 - val_loss: 0.0280 - val_mae: 0.0280 - val_mape: 8.7405
# Epoch 55/60
# 18/27 [===================>..........] - ETA: 0s - loss: 0.0200 - mae: 0.0200 - mape: 8.4383
# Epoch 55: val_loss did not improve from 0.02179
# 27/27 [==============================] - 0s 13ms/step - loss: 0.0197 - mae: 0.0197 - mape: 8.2580 - val_loss: 0.0327 - val_mae: 0.0327 - val_mape: 11.4464
# Epoch 56/60
# 17/27 [=================>............] - ETA: 0s - loss: 0.0201 - mae: 0.0201 - mape: 8.4720
# Epoch 56: val_loss did not improve from 0.02179
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0200 - mae: 0.0200 - mape: 8.9070 - val_loss: 0.0218 - val_mae: 0.0218 - val_mape: 7.5408
# Epoch 57/60
# 27/27 [==============================] - ETA: 0s - loss: 0.0200 - mae: 0.0200 - mape: 8.5666
# Epoch 57: val_loss did not improve from 0.02179
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0200 - mae: 0.0200 - mape: 8.5666 - val_loss: 0.0275 - val_mae: 0.0275 - val_mape: 7.5773
# Epoch 58/60
# 23/27 [========================>.....] - ETA: 0s - loss: 0.0197 - mae: 0.0197 - mape: 7.6669
# Epoch 58: val_loss did not improve from 0.02179
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0198 - mae: 0.0198 - mape: 8.5914 - val_loss: 0.0240 - val_mae: 0.0240 - val_mape: 6.7472
# Epoch 59/60
# 23/27 [========================>.....] - ETA: 0s - loss: 0.0194 - mae: 0.0194 - mape: 8.7043
# Epoch 59: val_loss did not improve from 0.02179
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0192 - mae: 0.0192 - mape: 8.3765 - val_loss: 0.0276 - val_mae: 0.0276 - val_mape: 9.7679
# Epoch 60/60
# 20/27 [=====================>........] - ETA: 0s - loss: 0.0213 - mae: 0.0213 - mape: 8.3646
# Epoch 60: val_loss did not improve from 0.02179
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0212 - mae: 0.0212 - mape: 8.7106 - val_loss: 0.0328 - val_mae: 0.0328 - val_mape: 11.4887

# %%
model = load_model(r'C:\Users\Lenovo\Documents\lab11\lab\E1-cp-0041-loss0.02.h5')

y_pred_scaled   = model.predict(test_X)
y_pred          = scaler.inverse_transform(y_pred_scaled)
y_test_unscaled = scaler.inverse_transform(test_y)
# Mean Absolute Error (MAE)
MAE = np.mean(abs(y_pred - y_test_unscaled)) 
print('Mean Absolute Error (MAE): ' + str(np.round(MAE, 2)))

# Median Absolute Error (MedAE)
MEDAE = np.median(abs(y_pred - y_test_unscaled))
print('Median Absolute Error (MedAE): ' + str(np.round(MEDAE, 2)))

# Mean Squared Error (MSE)
MSE = np.square(np.subtract(y_pred, y_test_unscaled)).mean()
print('Mean Squared Error (MSE): ' + str(np.round(MSE, 2)))

# Root Mean Squarred Error (RMSE) 
RMSE = np.sqrt(np.mean(np.square(y_pred - y_test_unscaled)))
print('Root Mean Squared Error (RMSE): ' + str(np.round(RMSE, 2)))

# Mean Absolute Percentage Error (MAPE)
MAPE = np.mean((np.abs(np.subtract(y_test_unscaled, y_pred)/ y_test_unscaled))) * 100
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE, 2)) + ' %')

# Median Absolute Percentage Error (MDAPE)
MDAPE = np.median((np.abs(np.subtract(y_test_unscaled, y_pred)/ y_test_unscaled))) * 100
print('Median Absolute Percentage Error (MDAPE): ' + str(np.round(MDAPE, 2)) + ' %')

print('\n\ny_test_unscaled.shape= ',y_test_unscaled.shape)
print('y_pred.shape= ',y_pred.shape)
# Out:
# 1/1 [==============================] - 0s 219ms/step
# Mean Absolute Error (MAE): 9978.49
# Median Absolute Error (MedAE): 10026.42
# Mean Squared Error (MSE): 99777932.18
# Root Mean Squared Error (RMSE): 9988.89
# Mean Absolute Percentage Error (MAPE): 63.72 %
# Median Absolute Percentage Error (MDAPE): 62.05 %
#
#
# y_test_unscaled.shape=  (5, 1)
# y_pred.shape=  (5, 1)

# %% [markdown]
# # Fine Tuning

# %%
checkpoints = r'C:\Users\Lenovo\Documents\lab11\lab\E2-cp-{epoch:04d}-loss{val_loss:.2f}.h5'
model=r'C:\Users\Lenovo\Documents\lab11\lab\E1-cp-0041-loss0.02.h5'
start_epoch= 56

# %%
# construct the callback to save only the *best* model to disk
# based on the validation loss
EpochCheckpoint1 = ModelCheckpoint(checkpoints,
                             monitor="val_loss",
                             save_best_only=True, 
                             verbose=1)
TrainingMonitor1=TrainingMonitor(FIG_PATH, jsonPath=JSON_PATH, startAt=start_epoch)

# construct the set of callbacks
callbacks = [EpochCheckpoint1,TrainingMonitor1]
# if there is no specific model checkpoint supplied, then initialize
# the network and compile the model
if model is None:
    print("[INFO] compiling model...")
    model = PC.build(time_steps=24, num_features=21, reg=0.0005)
    opt = Adam(1e-3)
    model.compile(loss= 'mae', optimizer=opt, metrics=["mae", "mape"])
# otherwise, load the checkpoint from disk
else:
    print("[INFO] loading {}...".format(model))
    model = load_model(model)

    # update the learning rate
    print("[INFO] old learning rate: {}".format(K.get_value(model.optimizer.lr)))
    K.set_value(model.optimizer.lr, 1e-4)
    print("[INFO] new learning rate: {}".format(K.get_value(model.optimizer.lr)))
# Out:
# [INFO] loading C:\Users\Lenovo\Documents\lab11\lab\E1-cp-0041-loss0.02.h5...
# [INFO] old learning rate: 0.0010000000474974513
# [INFO] new learning rate: 9.999999747378752e-05

# %%
epochs = 10
verbose = 1 #0
batch_size = 32
History = model.fit(train_X,
                        train_y,
                        batch_size=batch_size,   
                        epochs = epochs, 
                        validation_data = (validation_X,validation_y),
                        callbacks=callbacks,
                        verbose = verbose)
# Out:
# Epoch 1/10
# 19/27 [====================>.........] - ETA: 0s - loss: 0.0186 - mae: 0.0186 - mape: 8.6395
# Epoch 1: val_loss improved from inf to 0.02789, saving model to C:\Users\Lenovo\Documents\lab11\lab\E2-cp-0001-loss0.03.h5
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0185 - mae: 0.0185 - mape: 8.2474 - val_loss: 0.0279 - val_mae: 0.0279 - val_mape: 9.7811
# Epoch 2/10
# 23/27 [========================>.....] - ETA: 0s - loss: 0.0175 - mae: 0.0175 - mape: 7.7209
# Epoch 2: val_loss improved from 0.02789 to 0.02515, saving model to C:\Users\Lenovo\Documents\lab11\lab\E2-cp-0002-loss0.03.h5
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0175 - mae: 0.0175 - mape: 7.7704 - val_loss: 0.0251 - val_mae: 0.0251 - val_mape: 8.2414
# Epoch 3/10
# 22/27 [=======================>......] - ETA: 0s - loss: 0.0168 - mae: 0.0168 - mape: 7.4310
# Epoch 3: val_loss improved from 0.02515 to 0.02425, saving model to C:\Users\Lenovo\Documents\lab11\lab\E2-cp-0003-loss0.02.h5
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0165 - mae: 0.0165 - mape: 7.4267 - val_loss: 0.0242 - val_mae: 0.0242 - val_mape: 8.0321
# Epoch 4/10
# 17/27 [=================>............] - ETA: 0s - loss: 0.0165 - mae: 0.0165 - mape: 8.1877
# Epoch 4: val_loss did not improve from 0.02425
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0162 - mae: 0.0162 - mape: 7.1790 - val_loss: 0.0243 - val_mae: 0.0243 - val_mape: 7.9980
# Epoch 5/10
# 23/27 [========================>.....] - ETA: 0s - loss: 0.0160 - mae: 0.0160 - mape: 7.2683
# Epoch 5: val_loss did not improve from 0.02425
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0160 - mae: 0.0160 - mape: 7.2395 - val_loss: 0.0273 - val_mae: 0.0273 - val_mape: 9.4104
# Epoch 6/10
# 19/27 [====================>.........] - ETA: 0s - loss: 0.0160 - mae: 0.0160 - mape: 7.2925
# Epoch 6: val_loss did not improve from 0.02425
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0163 - mae: 0.0163 - mape: 7.3005 - val_loss: 0.0255 - val_mae: 0.0255 - val_mape: 8.5250
# Epoch 7/10
# 17/27 [=================>............] - ETA: 0s - loss: 0.0160 - mae: 0.0160 - mape: 7.1397
# Epoch 7: val_loss did not improve from 0.02425
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0161 - mae: 0.0161 - mape: 7.3050 - val_loss: 0.0257 - val_mae: 0.0257 - val_mape: 8.7518
# Epoch 8/10
# 17/27 [=================>............] - ETA: 0s - loss: 0.0160 - mae: 0.0160 - mape: 7.4735
# Epoch 8: val_loss improved from 0.02425 to 0.02390, saving model to C:\Users\Lenovo\Documents\lab11\lab\E2-cp-0008-loss0.02.h5
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0161 - mae: 0.0161 - mape: 7.0638 - val_loss: 0.0239 - val_mae: 0.0239 - val_mape: 7.7771
# Epoch 9/10
# 16/27 [================>.............] - ETA: 0s - loss: 0.0161 - mae: 0.0161 - mape: 7.4377
# Epoch 9: val_loss did not improve from 0.02390
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0165 - mae: 0.0165 - mape: 7.3220 - val_loss: 0.0250 - val_mae: 0.0250 - val_mape: 8.2501
# Epoch 10/10
# 15/27 [===============>..............] - ETA: 0s - loss: 0.0156 - mae: 0.0156 - mape: 7.2363
# Epoch 10: val_loss did not improve from 0.02390
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0160 - mae: 0.0160 - mape: 7.0525 - val_loss: 0.0280 - val_mae: 0.0280 - val_mape: 9.8338

# %%
model = load_model(r'C:\Users\Lenovo\Documents\lab11\lab\E2-cp-0008-loss0.02.h5')

y_pred_scaled   = model.predict(test_X)
y_pred          = scaler.inverse_transform(y_pred_scaled)
y_test_unscaled = scaler.inverse_transform(test_y)
# Mean Absolute Error (MAE)
MAE = np.mean(abs(y_pred - y_test_unscaled)) 
print('Mean Absolute Error (MAE): ' + str(np.round(MAE, 2)))

# Median Absolute Error (MedAE)
MEDAE = np.median(abs(y_pred - y_test_unscaled))
print('Median Absolute Error (MedAE): ' + str(np.round(MEDAE, 2)))

# Mean Squared Error (MSE)
MSE = np.square(np.subtract(y_pred, y_test_unscaled)).mean()
print('Mean Squared Error (MSE): ' + str(np.round(MSE, 2)))

# Root Mean Squarred Error (RMSE) 
RMSE = np.sqrt(np.mean(np.square(y_pred - y_test_unscaled)))
print('Root Mean Squared Error (RMSE): ' + str(np.round(RMSE, 2)))

# Mean Absolute Percentage Error (MAPE)
MAPE = np.mean((np.abs(np.subtract(y_test_unscaled, y_pred)/ y_test_unscaled))) * 100
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE, 2)) + ' %')

# Median Absolute Percentage Error (MDAPE)
MDAPE = np.median((np.abs(np.subtract(y_test_unscaled, y_pred)/ y_test_unscaled))) * 100
print('Median Absolute Percentage Error (MDAPE): ' + str(np.round(MDAPE, 2)) + ' %')

print('\n\ny_test_unscaled.shape= ',y_test_unscaled.shape)
print('y_pred.shape= ',y_pred.shape)
# Out:
# 1/1 [==============================] - 0s 278ms/step
# Mean Absolute Error (MAE): 10386.24
# Median Absolute Error (MedAE): 10370.18
# Mean Squared Error (MSE): 108049977.78
# Root Mean Squared Error (RMSE): 10394.71
# Mean Absolute Percentage Error (MAPE): 66.33 %
# Median Absolute Percentage Error (MDAPE): 64.91 %
#
#
# y_test_unscaled.shape=  (5, 1)
# y_pred.shape=  (5, 1)
